# %%
def read_file(path):
    with open(path, "r") as readfile:
        a = readfile.read()
        lines = a.split("\n")
    return lines

# %%
map = read_file("example-01.txt")
input = read_file("example-02.txt")[0]

# %%
map_new = []

for ix, line in enumerate(map):
    line_new = []
    for iy, char in enumerate(line):
        if char == "#":
            line_new.append(3)
        if  char == ".":
            line_new.append(0)
        if char == "O":
            line_new.append(1)
        if char == "@":
            position = (ix,iy)
            line_new.append(2)
    map_new.append(line_new)

# %%
print("Initial state")

for line in map:
    print(line)

for char in input:
    if char == "<":
        tentative_position = (position[0], position[1] - 1)
        if map_new[tentative_position[0]][tentative_position[1]] == 3:
            pass

        elif map_new[tentative_position[0]][tentative_position[1]] == 0:
            position = tentative_position
            map_new[position[0]][position[1] + 1] = 0
            map_new[position[0]][position[1]] = 2

        elif map_new[tentative_position[0]][tentative_position[1]] == 1:
            print(i)
    
    if char == ">":
        tentative_position = (position[0], position[1] + 1)
        if map_new[tentative_position[0]][tentative_position[1]] == 3:
            pass

        elif map_new[tentative_position[0]][tentative_position[1]] == 0:
            position = tentative_position
            map_new[position[0]][position[1] - 1] = 0
            map_new[position[0]][position[1]] = 2

        elif map_new[tentative_position[0]][tentative_position[1]] == 1:
            for i in range(position[1]+1, len(map[0])):
                in_between = []
                if map_new[position[0]][i] == 1:
                    in_between.append((position[0], i))
                if map_new[position[0]][i] == 0:
                    map_new[position[0]][position[1]] = 0
                    for index, pos in enumerate(in_between):
                        if index == 0:
                            map_new[pos[0]][pos[1]] = 2
                        else:
                            map_new[pos[0]][pos[1] + 1] = 1
                    break
                if map_new[position[0]][i] == 3:
                    break

    if char == "^":
        tentative_position = (position[0]-1, position[1])
        if map_new[tentative_position[0]][tentative_position[1]] == 3:
            pass

        elif map_new[tentative_position[0]][tentative_position[1]] == 0:
            map_new[position[0]][position[1]] = 0
            position = tentative_position
            map_new[position[0]][position[1]] = 2
        
        elif map_new[tentative_position[0]][tentative_position[1]] == 1 and map_new[tentative_position[0] - 1][tentative_position[1]] == 0:
            map_new[position[0]][position[1]] = 0
            position = tentative_position
            map_new[position[0]][position[1]] = 2
            map_new[position[0] - 1][position[1]] = 1

    if char == "v":
        tentative_position = (position[0]+1, position[1])
        if map_new[tentative_position[0]][tentative_position[1]] == 3:
            pass

        elif map_new[tentative_position[0]][tentative_position[1]] == 0:
            map_new[position[0]][position[1]] = 0
            position = tentative_position
            map_new[position[0]][position[1]] = 2
        
        elif map_new[tentative_position[0]][tentative_position[1]] == 1 and map_new[tentative_position[0] + 1][tentative_position[1]] == 0:
            map_new[position[0]][position[1]] = 0
            position = tentative_position
            map_new[position[0]][position[1]] = 2
            map_new[position[0] + 1][position[1]] = 1       




    map_conversion = []

    for ix, line in enumerate(map_new):
        line_conversion = []
        for iy, char_1 in enumerate(line):
            if char_1 == 3:
                line_conversion.append("#")
            if char_1 == 0:
                line_conversion.append(".")
            if  char_1 == 1:
                line_conversion.append("O")
            if position == (ix,iy):
                line_conversion.append("@")

        map_conversion.append(line_conversion)
    print(char)
    for line in map_conversion:
        print(line)

    print("\n")
# Out:
# Initial state
# ########
# #..O.O.#
# ##.@O..#
# #...O..#
# #.#.O..#
# #...O..#
# #......#
# ########
# <
# ['#', '#', '#', '#', '#', '#', '#', '#']
# ['#', '.', '.', 'O', '.', 'O', '.', '#']
# ['#', '#', '@', '.', 'O', '.', '.', '#']
# ['#', '.', '.', '.', 'O', '.', '.', '#']
# ['#', '.', '#', '.', 'O', '.', '.', '#']
# ['#', '.', '.', '.', 'O', '.', '.', '#']
# ['#', '.', '.', '.', '.', '.', '.', '#']
# ['#', '#', '#', '#', '#', '#', '#', '#']
#
#
# ^
# ['#', '#', '#', '#', '#', '#', '#', '#']
# ['#', '.', '@', 'O', '.', 'O', '.', '#']
# ['#', '#', '.', '.', 'O', '.', '.', '#']
# ['#', '.', '.', '.', 'O', '.', '.', '#']
# ['#', '.', '#', '.', 'O', '.', '.', '#']
# ['#', '.', '.', '.', 'O', '.', '.', '#']
# ['#', '.', '.', '.', '.', '.', '.', '#']
# ['#', '#', '#', '#', '#', '#', '#', '#']
#
#
# ^
# ['#', '#', '#', '#', '#', '#', '#', '#']
# ['#', '.', '@', 'O', '.', 'O', '.', '#']
# ['#', '#', '.', '.', 'O', '.', '.', '#']
# ['#', '.', '.', '.', 'O', '.', '.', '#']
# ...

# %%
print("Initial state")

for line in map:
    print(line)

for char in input:
    if char == "<":
        tentative_position = (position[0], position[1] - 1)
        if map_new[tentative_position[0]][tentative_position[1]] == 3:
            pass

        elif map_new[tentative_position[0]][tentative_position[1]] == 0:
            position = tentative_position
            map_new[position[0]][position[1] + 1] = 0
            map_new[position[0]][position[1]] = 2

        elif map_new[tentative_position[0]][tentative_position[1]] == 1 and map_new[tentative_position[0]][tentative_position[1] - 1] == 0:
            position = tentative_position
            map_new[position[0]][position[1]] = 2
            map_new[position[0]][position[1] - 1] = 1
    
    if char == ">":
        tentative_position = (position[0], position[1] + 1)
        if map_new[tentative_position[0]][tentative_position[1]] == 3:
            pass

        elif map_new[tentative_position[0]][tentative_position[1]] == 0:
            position = tentative_position
            map_new[position[0]][position[1] - 1] = 0
            map_new[position[0]][position[1]] = 2

        elif map_new[tentative_position[0]][tentative_position[1]] == 1 and map_new[tentative_position[0]][tentative_position[1] + 1] == 0:
            position = tentative_position
            map_new[position[0]][position[1] - 1] = 0
            map_new[position[0]][position[1]] = 2
            map_new[position[0]][position[1] + 1] = 1

    if char == "^":
        tentative_position = (position[0]-1, position[1])
        if map_new[tentative_position[0]][tentative_position[1]] == 3:
            pass

        elif map_new[tentative_position[0]][tentative_position[1]] == 0:
            map_new[position[0]][position[1]] = 0
            position = tentative_position
            map_new[position[0]][position[1]] = 2
        
        elif map_new[tentative_position[0]][tentative_position[1]] == 1 and map_new[tentative_position[0] - 1][tentative_position[1]] == 0:
            map_new[position[0]][position[1]] = 0
            position = tentative_position
            map_new[position[0]][position[1]] = 2
            map_new[position[0] - 1][position[1]] = 1

    if char == "v":
        tentative_position = (position[0]+1, position[1])
        if map_new[tentative_position[0]][tentative_position[1]] == 3:
            pass

        elif map_new[tentative_position[0]][tentative_position[1]] == 0:
            map_new[position[0]][position[1]] = 0
            position = tentative_position
            map_new[position[0]][position[1]] = 2
        
        elif map_new[tentative_position[0]][tentative_position[1]] == 1 and map_new[tentative_position[0] + 1][tentative_position[1]] == 0:
            map_new[position[0]][position[1]] = 0
            position = tentative_position
            map_new[position[0]][position[1]] = 2
            map_new[position[0] + 1][position[1]] = 1       




    map_conversion = []

    for ix, line in enumerate(map_new):
        line_conversion = []
        for iy, char_1 in enumerate(line):
            if char_1 == 3:
                line_conversion.append("#")
            if char_1 == 0:
                line_conversion.append(".")
            if  char_1 == 1:
                line_conversion.append("O")
            if position == (ix,iy):
                line_conversion.append("@")

        map_conversion.append(line_conversion)
    print(char)
    for line in map_conversion:
        print(line)

    print("\n")
# Out:
# Initial state
# ########
# #..O.O.#
# ##@.O..#
# #...O..#
# #.#.O..#
# #...O..#
# #......#
# ########
# <
# ['#', '#', '#', '#', '#', '#', '#', '#']
# ['#', '.', '.', '.', 'O', 'O', '.', '#']
# ['#', '#', '.', '.', 'O', '.', '.', '#']
# ['#', '@', '.', '.', '.', 'O', '.', '#']
# ['#', '.', '#', '.', 'O', '.', '.', '#']
# ['#', '.', '.', '.', 'O', '.', '.', '#']
# ['#', '.', '.', '.', '.', '.', '.', '#']
# ['#', '#', '#', '#', '#', '#', '#', '#']
#
#
# ^
# ['#', '#', '#', '#', '#', '#', '#', '#']
# ['#', '.', '.', '.', 'O', 'O', '.', '#']
# ['#', '#', '.', '.', 'O', '.', '.', '#']
# ['#', '@', '.', '.', '.', 'O', '.', '#']
# ['#', '.', '#', '.', 'O', '.', '.', '#']
# ['#', '.', '.', '.', 'O', '.', '.', '#']
# ['#', '.', '.', '.', '.', '.', '.', '#']
# ['#', '#', '#', '#', '#', '#', '#', '#']
#
#
# ^
# ['#', '#', '#', '#', '#', '#', '#', '#']
# ['#', '.', '.', '.', 'O', 'O', '.', '#']
# ['#', '#', '.', '.', 'O', '.', '.', '#']
# ['#', '@', '.', '.', '.', 'O', '.', '#']
# ...

# %%
map_conversion = []

for ix, line in enumerate(map_new):
    line_conversion = []
    for iy, char in enumerate(line):
        if char == 3:
            line_conversion.append("#")
        if char == 0:
            line_conversion.append(".")
        if  char == 1:
            line_conversion.append("O")
        if position == (ix,iy):
            line_conversion.append("@")

    map_conversion.append(line_conversion)

# %%
map_conversion
# Out:
# [['#', '#', '#', '#', '#', '#', '#', '#'],
#  ['#', '.', '.', 'O', '.', 'O', '.', '#'],
#  ['#', '#', '.', '@', '.', '.', 'O', '#'],
#  ['#', '.', '.', '.', 'O', '.', '.', '#'],
#  ['#', '.', '#', '.', 'O', '.', '.', '#'],
#  ['#', '.', '.', '.', 'O', '.', '.', '#'],
#  ['#', '.', '.', '.', '.', '.', '.', '#'],
#  ['#', '#', '#', '#', '#', '#', '#', '#']]
